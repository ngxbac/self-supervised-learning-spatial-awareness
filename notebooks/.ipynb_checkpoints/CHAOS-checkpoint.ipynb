# %%
import SimpleITK
import SimpleITK as sitk

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
UPPER_BOUND = 400
LOWER_BOUND = -1000

def norm_image(image):
    image = (image - LOWER_BOUND) / (UPPER_BOUND - LOWER_BOUND)
    image[image > 1] = 1.
    image[image < 0] = 0.
    image = image.astype(np.float32)
    return image

def load_ct_images(path):
    image = SimpleITK.ReadImage(path)
    image = SimpleITK.GetArrayFromImage(image).astype(np.float32)
    return image

def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

# %%
# !ls ../data/CHAOS/Train_Sets/MR/1/T1DUAL/DICOM_anon/InPhase/IMG-0004-00002.dcm
# Out:
# ../data/CHAOS/Train_Sets/MR/1/T1DUAL/DICOM_anon/InPhase/IMG-0004-00002.dcm

# %%
image = load_ct_images("../data/CHAOS/Train_Sets/CT/1/DICOM_anon/i0021,0000b.dcm")
image = norm_image(image[0])

# %%
plt.imshow(image, cmap="gray")

# %%
ymin, ymax, xmin, xmax = bbox(image > 0.5)
image = image[ymin:ymax, xmin:xmax]

# %%
plt.imshow(image)

# %%
np.unique(img)
# Out:
# array([  0,  63, 126, 189], dtype=uint8)
